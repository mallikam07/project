# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sb

# %%
df = pd.read_csv('dropout-ratio-2012-2015.csv',index_col='State_UT')

# %%
df
# Out:
#                    year Primary_Boys Primary_Girls Primary_Total  \
# State_UT
# A & N Islands   2012-13         0.83          0.51          0.68
# A & N Islands   2013-14         1.35          1.06          1.21
# A & N Islands   2014-15         0.47          0.55          0.51
# Andhra Pradesh  2012-13          3.3          3.05          3.18
# Andhra Pradesh  2013-14         4.31          4.39          4.35
# ...                 ...          ...           ...           ...
# West Bengal     2013-14         3.44          2.37          2.91
# West Bengal     2014-15         2.13          0.79          1.47
# All India       2012-13         4.68          4.66          4.67
# All India       2013-14         4.53          4.14          4.34
# All India       2014-15         4.36          3.88          4.13
#
#                Upper Primary_Boys Upper Primary_Girls Upper Primary_Total  \
# State_UT
# A & N Islands      Uppe_r_Primary                1.09                1.23
# ...

# %%
df['Primary_Girls'].value_counts().head(10).plot.bar( figsize=(10,5))
plt.show()

# %%
df.replace(to_replace='NR',value=0,inplace=True)

# %%
df.Primary_Boys = df.Primary_Boys.astype(float)
df.Primary_Girls = df.Primary_Girls.astype(float)

# %%
df.groupby('year').mean().plot(kind='line',figsize=(10,5))
plt.xlabel('Year')
plt.ylabel('Frequency')
plt.title('Primary student frequency from 2012-15')
# Out:
# Text(0.5, 1.0, 'Primary student frequency from 2012-15')

# %%
df.groupby('State_UT').mean().head(10).plot(kind='line',figsize=(20,4))
plt.xlabel('States')
plt.ylabel('Reach of Droupout Students- BOYS')
# Out:
# Text(0, 0.5, 'Reach of Droupout Students- BOYS')

# %%
df['Primary_Girls'].value_counts().head(10)
# Out:
# 0.00     15
# 1.06      4
# 5.02      2
# 3.05      2
# 0.59      2
# 0.39      2
# 10.03     2
# 3.49      2
# 1.98      1
# 0.38      1
# Name: Primary_Girls, dtype: int64

# %%
df.Primary_Girls= df.Primary_Girls.astype(float)

# %%
df.groupby('State_UT').mean().head(10).plot(kind='line',figsize=(10,5))
# Out:
# <AxesSubplot:xlabel='State_UT'>

# %%
df.groupby('Primary_Total').mean().head(10).plot(kind='line',figsize=(15,10))
plt.title('Total Primary Students VS Primary Boys and Primary Girls')
plt.xlabel('Primary Total Frequency')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
df.Primary_Total=df.Primary_Total.astype(float)

# %%
df
# Out:
#                    year  Primary_Boys  Primary_Girls  Primary_Total  \
# State_UT
# A & N Islands   2012-13          0.83           0.51           0.68
# A & N Islands   2013-14          1.35           1.06           1.21
# A & N Islands   2014-15          0.47           0.55           0.51
# Andhra Pradesh  2012-13          3.30           3.05           3.18
# Andhra Pradesh  2013-14          4.31           4.39           4.35
# ...                 ...           ...            ...            ...
# West Bengal     2013-14          3.44           2.37           2.91
# West Bengal     2014-15          2.13           0.79           1.47
# All India       2012-13          4.68           4.66           4.67
# All India       2013-14          4.53           4.14           4.34
# All India       2014-15          4.36           3.88           4.13
#
#                Upper Primary_Boys Upper Primary_Girls Upper Primary_Total  \
# State_UT
# ...

# %%
df.groupby('State_UT').mean().plot(kind='line',figsize=(20,5))
plt.xlabel('States')
plt.ylabel('Dropout Students Frequency')
plt.title( 'Ratio of Dropout Primary Students in States')
# Out:
# Text(0.5, 1.0, 'Ratio of Dropout Primary Students in States')

# %%
df.replace(to_replace='NR',value=0,inplace=True)

# %%
df
# Out:
#                    year  Primary_Boys  Primary_Girls  Primary_Total  \
# State_UT
# A & N Islands   2012-13          0.83           0.51           0.68
# A & N Islands   2013-14          1.35           1.06           1.21
# A & N Islands   2014-15          0.47           0.55           0.51
# Andhra Pradesh  2012-13          3.30           3.05           3.18
# Andhra Pradesh  2013-14          4.31           4.39           4.35
# ...                 ...           ...            ...            ...
# West Bengal     2013-14          3.44           2.37           2.91
# West Bengal     2014-15          2.13           0.79           1.47
# All India       2012-13          4.68           4.66           4.67
# All India       2013-14          4.53           4.14           4.34
# All India       2014-15          4.36           3.88           4.13
#
#                Upper Primary_Boys Upper Primary_Girls Upper Primary_Total  \
# State_UT
# ...

# %%
df['Upper Primary_Girls'].value_counts().head(10)
df['Upper Primary_Boys'].value_counts().head(10)
# Out:
# 0       16
# 2.37     2
# 3.21     2
# 3.46     2
# 0.89     2
# 5.46     1
# 0.37     1
# 0.33     1
# 4.11     1
# 3.11     1
# Name: Upper Primary_Boys, dtype: int64

# %%
df.groupby('year').mean().plot(kind='line',figsize=(20,5))
plt.title('Upper Primary StudentsDropout Data')
plt.ylabel('Frequency of Upper Primary Students')
plt.legend()

# %%
df['Upper Primary_Boys'].value_counts().head(10).plot()
df['Upper Primary_Girls'].value_counts().head(10).plot()
df['Upper Primary_Total'].value_counts().head(10).plot()
plt.xlabel('Upper Primary Students Data')
plt.ylabel('Upper Primary Total')
plt.title('Upper Primary Students VS Upper Primary Total')
plt.legend()

# %%
df.groupby('State_UT').mean().plot(figsize=(12,5))
# Out:
# <AxesSubplot:xlabel='State_UT'>

# %%
df['Upper Primary_Boys'].replace('Uppe_r_Primary',0,inplace=True)

# %%
df['Upper Primary_Girls']=df['Upper Primary_Girls'].astype(float)
df['Upper Primary_Boys']=df['Upper Primary_Boys'].astype(float)

# %%
b = df['Upper Primary_Boys']
c = df['Upper Primary_Girls']

# %%
b
# Out:
# State_UT
# A & N Islands     0.00
# A & N Islands     0.00
# A & N Islands     1.44
# Andhra Pradesh    3.21
# Andhra Pradesh    3.46
#                   ...
# West Bengal       5.63
# West Bengal       5.84
# All India         2.30
# All India         3.09
# All India         3.49
# Name: Upper Primary_Boys, Length: 110, dtype: float64

# %%
fig,ax = plt.subplots(1,1,figsize=(15,5))
b.plot(kind='line',ax=ax)
c.plot(kind='line',ax=ax)
plt.title('Data of Higher Secondary Students')
plt.xlabel('States')
plt.ylabel('Boys and Girls Status')
plt.legend()
plt.show()

# %%
df['HrSecondary_Boys']
# Out:
# State_UT
# A & N Islands     17.66
# A & N Islands     18.94
# A & N Islands     21.05
# Andhra Pradesh     2.66
# Andhra Pradesh    12.65
#                   ...
# West Bengal        8.03
# West Bengal        8.18
# All India             0
# All India          1.48
# All India          0.25
# Name: HrSecondary_Boys, Length: 110, dtype: object

# %%
df['Secondary _Girls'].replace('Secondar_y',0,inplace=True)

# %%
df['Secondary _Girls']=df['Secondary _Girls'].astype(float)
df['Secondary _Boys']=df['Secondary _Boys'].astype(float)

# %%
k=df['Secondary _Boys']
q=df['Secondary _Girls']

# %%
k
# Out:
# State_UT
# A & N Islands      5.57
# A & N Islands      8.36
# A & N Islands     11.47
# Andhra Pradesh    12.21
# Andhra Pradesh    11.95
#                   ...
# West Bengal       16.73
# West Bengal       16.33
# All India         14.54
# All India         17.93
# All India         17.21
# Name: Secondary _Boys, Length: 110, dtype: float64

# %%
fig,ax = plt.subplots(1,1,figsize=(15,5))
k.plot(kind='line',ax=ax)
q.plot(kind='line',ax=ax)
plt.title('Data of Secondary Students')
plt.xlabel('Years')
plt.ylabel('Boys and Girls Status')
plt.legend()
plt.show()

# %%
df['Upper Primary_Boys'].replace('Uppe_r_Primary',0,inplace=True)

# %%
df['HrSecondary_Boys'].replace('HrSecondar_y',0,inplace=True)

# %%
df['HrSecondary_Girls']=df['HrSecondary_Girls'].astype(float)
df['HrSecondary_Boys']=df['HrSecondary_Boys'].astype(float)

# %%
f = df['HrSecondary_Boys']
g = df['HrSecondary_Girls']

# %%
f
# Out:
# State_UT
# A & N Islands     17.66
# A & N Islands     18.94
# A & N Islands     21.05
# Andhra Pradesh     2.66
# Andhra Pradesh    12.65
#                   ...
# West Bengal        8.03
# West Bengal        8.18
# All India          0.00
# All India          1.48
# All India          0.25
# Name: HrSecondary_Boys, Length: 110, dtype: float64

# %%
fig,ax = plt.subplots(1,1,figsize=(15,5))
f.plot(kind='line',ax=ax)
g.plot(kind='line',ax=ax)
plt.title('Data of Secondary Students')
plt.xlabel('Years')
plt.ylabel('Boys and Girls Status')
plt.legend()
plt.show()
