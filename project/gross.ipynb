# %%
import numpy as np
import pandas as pd
import seaborn as sb 
import matplotlib.pyplot as plt

# %%
gd = pd.read_csv('gross-enrollment-ratio-2013-2016.csv',index_col='State_UT')

# %%
gd
# Out:
#                               Year  Primary_Boys  Primary_Girls  \
# State_UT
# Andaman & Nicobar Islands  2013-14         95.88          91.97
# Andhra Pradesh             2013-14         96.62          96.87
# Arunachal Pradesh          2013-14        129.12         127.77
# Assam                      2013-14        111.77         115.16
# Bihar                      2013-14         95.03         101.15
# ...                            ...           ...            ...
# Tripura                    2014-15        109.50         110.49
# Uttar Pradesh              2014-15         91.54          98.93
# Uttaranchal                2014-15        100.11         101.02
# West Bengal                2014-15        101.78         102.91
# All India                  2014-15         98.85         101.43
#
#                            Primary_Total  Upper_Primary_Boys  \
# State_UT
# Andaman & Nicobar Islands          93.93               94.70
# ...

# %%
gd.replace(to_replace='NR',value=0,inplace=True)

# %%
gd.Primary_Boys = gd.Primary_Boys.astype(float)
gd.Secondary_Boys = gd.Secondary_Boys.astype(float)
gd.Upper_Primary_Boys = gd.Upper_Primary_Boys.astype(float)

# %%
gd[['Primary_Boys','Secondary_Boys','Upper_Primary_Boys']]
# Out:
#                            Primary_Boys  Secondary_Boys  Upper_Primary_Boys
# State_UT
# Andaman & Nicobar Islands         95.88          102.89               94.70
# Andhra Pradesh                    96.62           73.76               82.81
# Arunachal Pradesh                129.12           88.37              112.64
# Assam                            111.77           65.60               87.85
# Bihar                             95.03           57.66               80.60
# ...                                 ...             ...                 ...
# Tripura                          109.50          119.81              118.80
# Uttar Pradesh                     91.54           67.85               68.14
# Uttaranchal                      100.11           90.99               84.20
# West Bengal                      101.78           70.67               96.16
# All India                         98.85           78.13               87.71
#
# [110 rows x 3 columns]

# %%
boys = gd['Primary_Boys']+gd['Upper_Primary_Boys']+gd['Secondary_Boys']

# %%
boys
# Out:
# State_UT
# Andaman & Nicobar Islands    293.47
# Andhra Pradesh               253.19
# Arunachal Pradesh            330.13
# Assam                        265.22
# Bihar                        233.29
#                               ...
# Tripura                      348.11
# Uttar Pradesh                227.53
# Uttaranchal                  275.30
# West Bengal                  268.61
# All India                    264.69
# Length: 110, dtype: float64

# %%
gd.Upper_Primary_Girls = gd.Upper_Primary_Girls.astype(float)
gd.Primary_Girls=gd.Primary_Girls.astype(float)
gd.Secondary_Girls=gd.Secondary_Girls.astype(float)

# %%
gd[['Upper_Primary_Girls','Primary_Girls','Secondary_Girls']]
# Out:
#                            Upper_Primary_Girls  Primary_Girls  Secondary_Girls
# State_UT
# Andaman & Nicobar Islands                88.98          91.97            97.36
# Andhra Pradesh                           84.38          96.87            76.77
# Arunachal Pradesh                       115.27         127.77            84.89
# Assam                                    98.69         115.16            77.20
# Bihar                                    94.92         101.15            62.96
# ...                                        ...            ...              ...
# Tripura                                 122.38         110.49           121.36
# Uttar Pradesh                            82.28          98.93            67.73
# Uttaranchal                              87.03         101.02            89.65
# West Bengal                             110.67         102.91            86.05
# All India                                95.29         101.43            78.94
#
# ...

# %%
girls = gd['Primary_Girls']+gd['Secondary_Girls']+gd['Upper_Primary_Girls']

# %%
girls
# Out:
# State_UT
# Andaman & Nicobar Islands    278.31
# Andhra Pradesh               258.02
# Arunachal Pradesh            327.93
# Assam                        291.05
# Bihar                        259.03
#                               ...
# Tripura                      354.23
# Uttar Pradesh                248.94
# Uttaranchal                  277.70
# West Bengal                  299.63
# All India                    275.66
# Length: 110, dtype: float64

# %%
gd.groupby('State_UT').mean()
# Out:
#                            Primary_Boys  Primary_Girls  Primary_Total  \
# State_UT
# All India                     98.973333     101.590000     100.216667
# Andaman & Nicobar Islands     93.306667      89.223333      91.260000
# Andhra Pradesh                89.936667      89.676667      89.810000
# Arunachal Pradesh            128.503333     127.033333     127.783333
# Assam                        109.953333     113.116667     111.500000
# Bihar                         99.156667     105.600000     102.240000
# Chandigarh                    83.153333      91.383333      86.800000
# Chhattisgarh                 102.510000     102.216667     102.363333
# Dadra & Nagar Haveli          86.533333      80.293333      83.496667
# Daman & Diu                   83.803333      87.366667      85.396667
# Delhi                        108.733333     113.830000     111.043333
# Goa                          102.963333     104.926667     103.893333
# ...

# %%
fig,ax = plt.subplots(1,1,figsize=(15,5))
boys.plot(kind='line',ax=ax)
girls.plot(kind='line',ax=ax)
plt.title('BOYS AND GIRLS RATIO VS STATES ')
plt.xlabel('STATES',size=20)
plt.ylabel('BOYS AND POPULATION')
plt.legend(boys,girls)
plt.show()
# Out:
# C:\Users\MALLIK~1\AppData\Local\Temp/ipykernel_14144/110448300.py:7: UserWarning: Legend does not support 293.46999999999997 instances.
# A proxy artist may be used instead.
# See: https://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#   plt.legend(boys,girls)
# C:\Users\MALLIK~1\AppData\Local\Temp/ipykernel_14144/110448300.py:7: UserWarning: Legend does not support 253.19 instances.
# A proxy artist may be used instead.
# See: https://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#   plt.legend(boys,girls)
# C:\Users\MALLIK~1\AppData\Local\Temp/ipykernel_14144/110448300.py:7: UserWarning: Legend does not support 330.13 instances.
# A proxy artist may be used instead.
# See: https://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#   plt.legend(boys,girls)
# ...

# %%
gd.groupby('')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\MALLIK~1\AppData\Local\Temp/ipykernel_14144/3490583451.py in <module>
# ----> 1 gd.groupby('')
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7624         # error: Argument "squeeze" to "DataFrameGroupBy" has incompatible type
#    7625         # "Union[bool, NoDefault]"; expected "bool"
# -> 7626         return DataFrameGroupBy(
#    7627             obj=self,
#    7628             keys=by,
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     886             from pandas.core.groupby.grouper import get_grouper
# ...
